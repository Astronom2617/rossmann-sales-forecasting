# %% [markdown]
# <a href="https://colab.research.google.com/github/Astronom2617/rossmann-sales-forecasting/blob/main/rossmann_summary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

train = pd.read_csv('/content/drive/MyDrive/rossmann/train.csv',
                    parse_dates=['Date'], low_memory=False)
store = pd.read_csv('/content/drive/MyDrive/rossmann/store.csv')
test = pd.read_csv('/content/drive/MyDrive/rossmann/test.csv',
                   parse_dates=['Date'])

# %%
models = ['Mean per store', 'Mean per store+day', 'SARIMA', 'XGBoost']
rmse_values = [3267, 2014, 2140, 1632]

# %%
fig, ax = plt.subplots()

ax.bar(models, rmse_values,
       width=1, edgecolor="white", linewidth=0.7)

colors = ['steelblue', 'steelblue', 'steelblue', 'darkorange']
plt.bar(models, rmse_values, color=colors)

plt.xticks(rotation=15, ha='right')

plt.title('Model Comparison — RMSE')
plt.xlabel('Model')
plt.ylabel('RMSE (€)')
plt.show()

# %% [markdown]
# # **Summary Conclusion**
#
# **Our overall winner: XGBoost**!
#
# It performed **best in RMSE (€1632)** because it leverages multiple features — promotions, store type, lag sales, and seasonality — that both Baseline and SARIMA ignored, making it the best solution for this task among the models tested.
#
# What's next? We could improve and tinker with XGBoost's features and parameters, or perhaps find other models that might be suitable for this task.
